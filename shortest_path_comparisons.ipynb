# %% [markdown]
# <a href="https://colab.research.google.com/github/JasLaras/passagemath-workspace/blob/main/shortest_path_comparisons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Comparison of Combinatorial and Optimization Methods for Graph Problems**
#
# ***Goal:***
#
# Compare combinatorial shortest-path algorithms (Dijkstra, Bellman-Ford) with optimization-based methods (Linear Programming).
#
# ***Focus:***
# *   runtime
# *   scalability
# *   graph structure sensitivity

# %%
# !pip install passagemath-polyhedra
# Out:
# Collecting passagemath-polyhedra
#   Downloading passagemath_polyhedra-10.8.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (17 kB)
# Collecting gmpy2~=2.1.b999 (from passagemath-polyhedra)
#   Downloading gmpy2-2.4.0a0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting cysignals!=1.12.0,>=1.11.2 (from passagemath-polyhedra)
#   Downloading cysignals-1.12.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting passagemath-ppl (from passagemath-polyhedra)
#   Downloading passagemath_ppl-0.8.10.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting memory_allocator<0.2 (from passagemath-polyhedra)
#   Downloading memory_allocator-0.1.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting passagemath-environment~=10.8.4.0 (from passagemath-polyhedra)
#   Downloading passagemath_environment-10.8.4-py3-none-any.whl.metadata (6.7 kB)
# Collecting passagemath-glpk~=10.8.4.0 (from passagemath-polyhedra)
#   Downloading passagemath_glpk-10.8.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting passagemath-modules~=10.8.4.0 (from passagemath-polyhedra)
#   Downloading passagemath_modules-10.8.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from memory_allocator<0.2->passagemath-polyhedra) (3.0.12)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from passagemath-environment~=10.8.4.0->passagemath-polyhedra) (26.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from passagemath-environment~=10.8.4.0->passagemath-polyhedra) (4.9.6)
# Collecting passagemath-objects~=10.8.4.0 (from passagemath-glpk~=10.8.4.0->passagemath-polyhedra)
#   Downloading passagemath_objects-10.8.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Collecting passagemath-categories~=10.8.4.0 (from passagemath-modules~=10.8.4.0->passagemath-polyhedra)
#   Downloading passagemath_categories-10.8.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from passagemath-modules~=10.8.4.0->passagemath-polyhedra) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from passagemath-objects~=10.8.4.0->passagemath-glpk~=10.8.4.0->passagemath-polyhedra) (4.15.0)
# Downloading passagemath_polyhedra-10.8.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 54.6 MB/s eta 0:00:00
# Downloading cysignals-1.12.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.7/270.7 kB 20.2 MB/s eta 0:00:00
# Downloading gmpy2-2.4.0a0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.5 MB/s eta 0:00:00
# Downloading memory_allocator-0.1.4-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.2/540.2 kB 25.5 MB/s eta 0:00:00
# Downloading passagemath_environment-10.8.4-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 12.3 MB/s eta 0:00:00
# Downloading passagemath_glpk-10.8.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 75.3 MB/s eta 0:00:00
# Downloading passagemath_modules-10.8.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (79.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 MB 9.8 MB/s eta 0:00:00
# Downloading passagemath_ppl-0.8.10.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 21.9 MB/s eta 0:00:00
# Downloading passagemath_categories-10.8.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (46.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 13.8 MB/s eta 0:00:00
# Downloading passagemath_objects-10.8.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (18.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.4/18.4 MB 25.0 MB/s eta 0:00:00
# Installing collected packages: passagemath-environment, memory_allocator, gmpy2, cysignals, passagemath-ppl, passagemath-objects, passagemath-glpk, passagemath-categories, passagemath-modules, passagemath-polyhedra
# Successfully installed cysignals-1.12.6 gmpy2-2.4.0a0 memory_allocator-0.1.4 passagemath-categories-10.8.4 passagemath-environment-10.8.4 passagemath-glpk-10.8.4 passagemath-modules-10.8.4 passagemath-objects-10.8.4 passagemath-polyhedra-10.8.4 passagemath-ppl-0.8.10.2

# %%
from sage.numerical.mip import MixedIntegerLinearProgram

import heapq
import time
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# We consider the single-source shortest path problem on a weighted directed graph G = (V,E),
#
# where each edge \(u,v) ∈ E has weight w(u,v) ≥ 0.
#
# The goal is to compute:
#
# $$
# \mathrm{dist}(s, v) = \min_{P: s \to v} \sum_{(u, v) \in P} w(u, v)
# $$

# %%
# tiny weighted graph as adjacency list

G = {
    0: [(1, 1), (2, 4)],
    1: [(2, 2), (3, 6)],
    2: [(3, 3)],
    3: []
}

# %%
DG = nx.DiGraph()

for u in G:
    for v, w in G[u]:
        DG.add_edge(u, v, weight=w)

pos = nx.spring_layout(DG)

nx.draw(DG, pos, with_labels=True)
nx.draw_networkx_edge_labels(DG, pos, edge_labels=nx.get_edge_attributes(DG, 'weight'))

plt.show()

# %% [markdown]
# ### Dijkstra’s Algorithm
#
# Dijkstra maintains a set of visited nodes and iteratively selects the node with minimum tentative distance.
#
# Update rule:
# $$
# d(v) = min(d(v),d(u) + w(u,v))
# $$
#
# Time complexity:
# $$
# O((|V|+|E|)log|V|)
# $$
#
# Key idea: greedy selection of locally optimal edges leads to global optimality (only valid for **nonnegative weights**).

# %%
def run_dijkstra(G, start=0, target=3):

    dist = {node: float('inf') for node in G}
    dist[start] = 0

    pq = [(0, start)]

    while pq:
        d, u = heapq.heappop(pq)

        if u == target:
            return d

        for v, w in G[u]:
            if dist[v] > d + w:
                dist[v] = d + w
                heapq.heappush(pq, (dist[v], v))

    return dist[target]

# %% [markdown]
# ### Bellman–Ford Algorithm
#
# Bellman–Ford repeatedly relaxes **all edges**:
#
# $$
# d^{(k)}(v) = \min(d^{(k-1)}(v),\ d^{(k-1)}(u) + w(u,v))
# $$
#
# After at most |V|-1 iterations, all shortest paths are found.
#
# Time complexity:
# $$
# O(|V||E|)
# $$
#
# Key idea: propagates improvements iteratively across the graph and can handle negative weights.

# %%
def run_bellman_ford(G, start=0):

    dist = {node: float('inf') for node in G}
    dist[start] = 0

    edges = [(u, v, w) for u in G for v, w in G[u]]

    n = len(G)

    for _ in range(n - 1):
        for u, v, w in edges:
            if dist[u] + w < dist[v]:
                dist[v] = dist[u] + w

    return dist

# %% [markdown]
# ### Linear Programming Formulation (Optimization Approach)
#
# Shortest path can be formulated as a linear program:
#
# $$
# \min \sum_{(u,v)\in E} w(u,v)x_{uv}
# $$
#
# subject to flow constraints:
#
# - Flow conservation:
# $$
# \sum_{(u,v)\in E} x_{uv} - \sum_{(v,u)\in E} x_{vu} =
# \begin{cases}
# 1 & \text{if } v = s \\
# -1 & \text{if } v = t \\
# 0 & \text{otherwise}
# \end{cases}
# $$
#
# - Capacity constraints:
# $$
# x_{uv} \ge 0
# $$
#
# Time complexity depends on the LP solver, but with significantly higher constants in practice.

# %%
def run_lp():

    p = MixedIntegerLinearProgram(maximization=False)
    x = p.new_variable(nonnegative=True)

    edges = [
        (0,1,1),
        (0,2,4),
        (1,2,2),
        (1,3,6),
        (2,3,3)
    ]

    p.set_objective(sum(w * x[(u,v)] for u,v,w in edges))

    # flow constraints
    p.add_constraint(x[(0,1)] + x[(0,2)] == 1)
    p.add_constraint(x[(0,1)] - x[(1,2)] - x[(1,3)] == 0)
    p.add_constraint(x[(0,2)] + x[(1,2)] - x[(2,3)] == 0)
    p.add_constraint(x[(1,3)] + x[(2,3)] == 1)

    p.solve()

    return p.get_objective_value()

# %% [markdown]
# ### Summary of Methods
#
# - Dijkstra: **greedy** combinatorial optimization
# - Bellman–Ford: **dynamic** relaxation process
# - LP: global constraint optimization formulation

# %%
def time_function(func, *args):

    start = time.time()
    result = func(*args)
    end = time.time()

    return result, end - start

# %%
dijkstra_result, t_dijkstra = time_function(run_dijkstra, G)
bf_result, t_bf = time_function(run_bellman_ford, G)
lp_result, t_lp = time_function(run_lp)

print("Dijkstra shortest path:", dijkstra_result)
print("Bellman-Ford distances:", bf_result)
print("LP cost:", lp_result)
# Out:
# Dijkstra shortest path: 6
# Bellman-Ford distances: {0: 0, 1: 1, 2: 3, 3: 6}
# LP cost: 6.0

# %%
print("\n--- Runtime Comparison ---")
print("Dijkstra:", t_dijkstra)
print("Bellman-Ford:", t_bf)
print("LP:", t_lp)
# Out:
# --- Runtime Comparison ---
# Dijkstra: 2.4318695068359375e-05
# Bellman-Ford: 1.2636184692382812e-05
# LP: 0.0009450912475585938

# %% [markdown]
# ### Runtime Comparison
#
# - Dijkstra: **fastest** (greedy structure exploitation)
# - Bellman–Ford: **slightly slower** due to repeated edge relaxation
# - LP: **significantly slower** due to general-purpose optimization overhead

# %% [markdown]
# ### Key Insight
#
# Although all methods solve the same shortest path problem, their **efficiency differs** because they exploit different mathematical structures:
#
# - Combinatorial algorithms use graph-specific structure
# - LP formulation encodes the problem as a general optimization system
#
# As a result, **LP provides flexibility and generality**, but at the cost of computational efficiency.
